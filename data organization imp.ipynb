# %%
import mysql.connector

# %%
import pandas as pd

# %%
mydb=mysql.connector.connect(host="localhost",user="root",password="Cmpunk@007",database="dailysales")

# %%
df=pd.read_sql("select * from sales",mydb)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7660\1746032488.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql("select * from sales",mydb)

# %%
df
# Out:
#   sales_id bde_name prod_name  cost
# 0        1     Ravi      Pen   1000

# %%
df2=pd.read_csv("sample.csv")

# %%
df2
# Out:
#       Index  Organization Id                         Name
# 0         1  522816eF8fdBE6d                 Mckinney PLC  \
# 1         2  70C7FBD7e6Aa3Ea               Cunningham LLC
# 2         3  428B397eA2d7290                   Ruiz-Walls
# 3         4  9D234Ae8Cc51C1c  Parrish, Osborne and Clarke
# 4         5  6CDCcdE3D0b7b44       Diaz, Robles and Haley
# ...     ...              ...                          ...
# 9995   9996  2EE82AD1Cd045cd           Neal, Day and Wang
# 9996   9997  06f1568A2CaF04a    Barrett, Rojas and Adkins
# 9997   9998  B4B92A44e0331Bc               Franklin-Ayala
# 9998   9999  01D2539e270CEbd                  Wolfe-Mckee
# 9999  10000  0D3b7DcFA21d92d                     Beck LLC
#
#                             Website
# 0                  http://soto.com/  \
# 1         http://harding-duffy.com/
# 2            http://www.atkins.biz/
# 3              http://salazar.info/
# 4     https://www.brooks-scott.net/
# ...                             ...
# ...

# %%
from google_auth_oauthlib.flow import InstalledAppFlow

# %%
f=InstalledAppFlow.from_client_secrets_file("keyy.json",['https://www.googleapis.com/auth/spreadsheets'])

# %%
cred=f.run_local_server(port=0)
