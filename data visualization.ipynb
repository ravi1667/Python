# %%
import pandas as pd
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df=pd.read_csv('emp.txt')

# %%
df
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %
# 0     Douglas    Male    8/6/1993        12:42 PM   97308    6.945  \
# 1      Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2       Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3       Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4       Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5      Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6        Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7         NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8      Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9     Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 10     Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11     Gloria  Female  10/24/1987         4:43 AM   39833    9.631
# 12     Albert    Male   9/19/1992         2:35 AM   45094    5.850
# ...

# %%
#scatterplot
sns.scatterplot(x=df['Salary'],y=df['Bonus %'],hue=df['Senior Management'])
# Out:
# <Axes: xlabel='Salary', ylabel='Bonus %'>

# %%
sns.displot(x=df['Salary'])

# %%
sns.displot(x=df['Salary'])

# %%
sns.countplot(x=df['Senior Management'])
# Out:
# <Axes: xlabel='Senior Management', ylabel='count'>

# %%
df2=pd.read_csv('volume.csv')

# %%
df2
# Out:
#     year  sale_of_newater
# 0   2007            49.15
# 1   2008            65.99
# 2   2009            71.95
# 3   2010            96.40
# 4   2011           102.40
# 5   2012           111.40
# 6   2013           114.10
# 7   2014           117.10
# 8   2015           124.80
# 9   2016           126.90
# 10  2017           140.20
# 11  2018           140.50
# 12  2019           145.50

# %%
df3=df2[0:11]

# %%
df3
# Out:
#    year  sale_of_newater
# 0  2007            49.15
# 1  2008            65.99
# 2  2009            71.95
# 3  2010            96.40
# 4  2011           102.40
# 5  2012           111.40
# 6  2013           114.10

# %%
sns.lineplot(x=df3['year'],y=df3['sale_of_newater'])
# Out:
# <Axes: xlabel='year', ylabel='sale_of_newater'>

# %%
df3
# Out:
#     year  sale_of_newater
# 0   2007            49.15
# 1   2008            65.99
# 2   2009            71.95
# 3   2010            96.40
# 4   2011           102.40
# 5   2012           111.40
# 6   2013           114.10
# 7   2014           117.10
# 8   2015           124.80
# 9   2016           126.90
# 10  2017           140.20

# %%
sns.lineplot(x=df3['year'],y=df3['sale_of_newater'])
# Out:
# <Axes: xlabel='year', ylabel='sale_of_newater'>

# %%
sns.barplot(x=['Youtube','Seo','Social media'],y=[2330,2445,2000])
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(x=[34,45,67],labels=['Youtube 34','Seo 45','Social media 67'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2b5951b5cd0>,
# ...
#  [Text(0.8185143206633013, 0.7348702653319797, 'Youtube 34'),
#   Text(-0.834136384727877, 0.7170889008157268, 'Seo 45'),
#   Text(0.14162296861546314, -1.0908450553403741, 'Social media 67')])
