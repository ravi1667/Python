# %%
import pandas as pd
df=pd.read_csv('netflix.csv')

# %%
df
# Out:
#      show_id     type                  title         director
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country
# 0                                                   NaN  United States  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df=df.drop(columns=['show_id','country','date_added'])

# %%
df
# Out:
#          type                  title         director
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1     TV Show          Blood & Water              NaN
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans              NaN
# 4     TV Show           Kota Factory              NaN
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb              NaN
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom     Peter Hewitt
# 8806    Movie                 Zubaan      Mozez Singh
#
#                                                    cast  release_year rating
# 0                                                   NaN          2020  PG-13  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...          2021  TV-MA
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...          2021  TV-MA
# ...

# %%
df.isnull().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
y=df[df['director'].isnull()].index

# %%
y
# Out:
# Index([   1,    3,    4,   10,   14,   15,   17,   19,   21,   25,
#        ...
#        8775, 8780, 8783, 8784, 8785, 8795, 8796, 8797, 8800, 8803],
#       dtype='int64', length=2634)

# %%
df.drop(index=y, inplace=True)

# %%
df
# Out:
#          type                             title
# 0       Movie              Dick Johnson Is Dead  \
# 2     TV Show                         Ganglands
# 5     TV Show                     Midnight Mass
# 6       Movie  My Little Pony: A New Generation
# 7       Movie                           Sankofa
# ...       ...                               ...
# 8801    Movie                           Zinzana
# 8802    Movie                            Zodiac
# 8804    Movie                        Zombieland
# 8805    Movie                              Zoom
# 8806    Movie                            Zubaan
#
#                            director
# 0                   Kirsten Johnson  \
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# 8801                Majid Al Ansari
# 8802                  David Fincher
# 8804                Ruben Fleischer
# ...

# %%
df.isnull().sum()
# Out:
# type              0
# title             0
# director          0
# cast            473
# release_year      0
# rating            1
# duration          3
# listed_in         0
# description       0
# dtype: int64

# %%
z=df[df['cast'].isnull()].index

# %%
z
# Out:
# Index([   0,   16,   20,   45,   91,  101,  102,  110,  117,  185,
#        ...
#        8707, 8723, 8727, 8728, 8738, 8739, 8744, 8746, 8756, 8763],
#       dtype='int64', length=473)

# %%
df.drop(index=z, inplace=True)

# %%
df
# Out:
#          type                             title
# 2     TV Show                         Ganglands  \
# 5     TV Show                     Midnight Mass
# 6       Movie  My Little Pony: A New Generation
# 7       Movie                           Sankofa
# 8     TV Show     The Great British Baking Show
# ...       ...                               ...
# 8801    Movie                           Zinzana
# 8802    Movie                            Zodiac
# 8804    Movie                        Zombieland
# 8805    Movie                              Zoom
# 8806    Movie                            Zubaan
#
#                            director
# 2                   Julien Leclercq  \
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 8                   Andy Devonshire
# ...                             ...
# 8801                Majid Al Ansari
# 8802                  David Fincher
# 8804                Ruben Fleischer
# ...

# %%
df.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# release_year    0
# rating          1
# duration        3
# listed_in       0
# description     0
# dtype: int64

# %%
df
# Out:
#          type                             title
# 2     TV Show                         Ganglands  \
# 5     TV Show                     Midnight Mass
# 6       Movie  My Little Pony: A New Generation
# 7       Movie                           Sankofa
# 8     TV Show     The Great British Baking Show
# ...       ...                               ...
# 8801    Movie                           Zinzana
# 8802    Movie                            Zodiac
# 8804    Movie                        Zombieland
# 8805    Movie                              Zoom
# 8806    Movie                            Zubaan
#
#                            director
# 2                   Julien Leclercq  \
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 8                   Andy Devonshire
# ...                             ...
# 8801                Majid Al Ansari
# 8802                  David Fincher
# 8804                Ruben Fleischer
# ...

# %%
duplicate_rows = df[df.duplicated()]

# %%
print(duplicate_rows.index)
# Out:
# Index([], dtype='int64')
