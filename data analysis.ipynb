# %%
import pandas as pd

# %%
df=pd.read_csv('laptop.csv')

# %%
df
# Out:
#     Company    Rating  No_of_ratings  Review  Size  RAM
# 0        HP  4.200000            253      20    36   16  \
# 1    Lenovo  4.200000            974      75    36    8
# 2      ASUS  4.400000           5389     535    40    8
# 3      DELL  4.100000            332      26    40    8
# 4      ASUS  4.200000            487      53    40    8
# ..      ...       ...            ...     ...   ...  ...
# 979  Lenovo  4.300000            252      29    40    8
# 980     MSI  3.600000             73      15    40    8
# 981  Lenovo  4.253597           2841     241    34   16
# 982   Avita  4.100000           2581     494    36    8
# 983  Lenovo  4.200000            265      21    40    8
#
#                                       Memory
# 0                                 512 GB SSD  \
# 1                                 256 GB SSD
# 2                                 512 GB SSD
# 3    Display: 15.6" FHD WVA AG Narrow Border
# 4                                 512 GB SSD
# ...

# %%
#descriptive analysis
import seaborn as sns

# %%
df.isnull().sum()
# Out:
# Company          0
# Rating           0
# No_of_ratings    0
# Review           0
# Size             0
# RAM              0
# Memory           0
# OpSys            0
# MRP              0
# dtype: int64

# %%
sns.scatterplot(x=df['Rating'],y=df['Size'],hue=df['Company'])
# Out:
# <Axes: xlabel='Rating', ylabel='Size'>

# %%
#As per the above graph, we cand find that most preferable laptop size to provide is between 30 and 50.
#Laptop with size more than 85 usually get a decent rating rather than  a bad rating.

# %%
sns.scatterplot(x=df['MRP'],y=df['Rating'])
# Out:
# <Axes: xlabel='MRP', ylabel='Rating'>

# %%
y=df[df['Rating']<3.5].index

# %%
y
# Out:
# Index([ 67, 167, 192, 287, 359, 437, 455, 479, 506, 527, 530, 551, 647, 671,
#        695, 815, 853, 857, 861, 880, 887],
#       dtype='int64')

# %%
df2=df.drop(index=y,inplace=True)

# %%
df2

# %%
df
# Out:
#     Company    Rating  No_of_ratings  Review  Size  RAM
# 0        HP  4.200000            253      20    36   16  \
# 1    Lenovo  4.200000            974      75    36    8
# 2      ASUS  4.400000           5389     535    40    8
# 3      DELL  4.100000            332      26    40    8
# 4      ASUS  4.200000            487      53    40    8
# ..      ...       ...            ...     ...   ...  ...
# 979  Lenovo  4.300000            252      29    40    8
# 980     MSI  3.600000             73      15    40    8
# 981  Lenovo  4.253597           2841     241    34   16
# 982   Avita  4.100000           2581     494    36    8
# 983  Lenovo  4.200000            265      21    40    8
#
#                                       Memory
# 0                                 512 GB SSD  \
# 1                                 256 GB SSD
# 2                                 512 GB SSD
# 3    Display: 15.6" FHD WVA AG Narrow Border
# 4                                 512 GB SSD
# ...

# %%
sns.scatterplot(x=df['MRP'],y=df['Rating'])
# Out:
# <Axes: xlabel='MRP', ylabel='Rating'>

# %%
#As per the above graph, we notice that ratings for products when moved up the MRP, it stays constant at 4.2 rating except few laptops sizes
#the best MRP to produce a laptop is between 50,000 to 2,00,000.

# %%
sns.scatterplot(x=df['Rating'],y=df['Review'])
# Out:
# <Axes: xlabel='Rating', ylabel='Review'>

# %%
#According to above graph we do notice that companies like MI, Gigabyte, realme, alienware,primebook,avita,nokia,lg and vaio just produce limited brands and still be successful with good ratings on marketing while other companies, do produce lot of products and ratings are fluctating between 3.5 and 5

# %%
sns.scatterplot(x=df['Rating'],y=df['RAM'],hue=df['Company'])
# Out:
# <Axes: xlabel='Rating', ylabel='RAM'>

# %%
#According to above graph we do notice that when ram is 32GB,
#it's good enough to be a successful product irrespective of company as they produce above 4.2 rating with

# %%
#Diagonstic analysis
#Majority of people prefer a laptop between 50,000 to 2,00,000 irrespective of company
#Majority of people love laptop with higher RAM
#Companies with less products do have higher ratings than companies working on various laptop in which ratings are fluctating.

# %%
#Predictive analysis

# %%
dummies = pd.get_dummies(df['Company'])

# %%
df = pd.concat([df, dummies], axis=1)

# %%
df
# Out:
#     Company    Rating  No_of_ratings  Review  Size  RAM
# 0        HP  4.200000            253      20    36   16  \
# 1    Lenovo  4.200000            974      75    36    8
# 2      ASUS  4.400000           5389     535    40    8
# 3      DELL  4.100000            332      26    40    8
# 4      ASUS  4.200000            487      53    40    8
# ..      ...       ...            ...     ...   ...  ...
# 979  Lenovo  4.300000            252      29    40    8
# 980     MSI  3.600000             73      15    40    8
# 981  Lenovo  4.253597           2841     241    34   16
# 982   Avita  4.100000           2581     494    36    8
# 983  Lenovo  4.200000            265      21    40    8
#
#                                       Memory
# 0                                 512 GB SSD  \
# 1                                 256 GB SSD
# 2                                 512 GB SSD
# 3    Display: 15.6" FHD WVA AG Narrow Border
# 4                                 512 GB SSD
# ...

# %%
#drop charges
X=df.drop(columns=['MRP','Company','OpSys','Memory','No_of_ratings','Review'])

# %%
X
# Out:
#        Rating  Size  RAM  ALIENWARE  APPLE   ASUS  Avita   DELL  GIGABYTE
# 0    4.200000    36   16      False  False  False  False  False     False  \
# 1    4.200000    36    8      False  False  False  False  False     False
# 2    4.400000    40    8      False  False   True  False  False     False
# 3    4.100000    40    8      False  False  False  False   True     False
# 4    4.200000    40    8      False  False   True  False  False     False
# ..        ...   ...  ...        ...    ...    ...    ...    ...       ...
# 979  4.300000    40    8      False  False  False  False  False     False
# 980  3.600000    40    8      False  False  False  False  False     False
# 981  4.253597    34   16      False  False  False  False  False     False
# 982  4.100000    36    8      False  False  False   True  False     False
# 983  4.200000    40    8      False  False  False  False  False     False
#
#         HP  ...  Lenovo    MSI     Mi  Nokia  Primebook  RedmiBook  SAMSUNG
# ...

# %%
Y=df['MRP']

# %%
Y
# Out:
# 0      59240
# 1      60890
# 2      70990
# 3      58489
# 4      50990
#        ...
# 979    93690
# 980    89990
# 981    76890
# 982    54490
# 983    76890
# Name: MRP, Length: 963, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
mymodel=LinearRegression()

# %%
df
# Out:
#     Company    Rating  No_of_ratings  Review  Size  RAM
# 0        HP  4.200000            253      20    36   16  \
# 1    Lenovo  4.200000            974      75    36    8
# 2      ASUS  4.400000           5389     535    40    8
# 3      DELL  4.100000            332      26    40    8
# 4      ASUS  4.200000            487      53    40    8
# ..      ...       ...            ...     ...   ...  ...
# 979  Lenovo  4.300000            252      29    40    8
# 980     MSI  3.600000             73      15    40    8
# 981  Lenovo  4.253597           2841     241    34   16
# 982   Avita  4.100000           2581     494    36    8
# 983  Lenovo  4.200000            265      21    40    8
#
#                                       Memory
# 0                                 512 GB SSD  \
# 1                                 256 GB SSD
# 2                                 512 GB SSD
# 3    Display: 15.6" FHD WVA AG Narrow Border
# 4                                 512 GB SSD
# ...

# %%
mymodel.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
mymodel.score(X_test,Y_test)
# Out:
# 0.4326832775463584

# %%
mymodel.coef_
# Out:
# array([ 3.37686950e+04,  1.92873961e+02,  7.15770225e+03,  1.99207447e+05,
#        -2.43006363e+04,  1.27604064e+04, -1.13039896e+04,  3.30207966e+03,
#         7.10817877e+03, -3.52737388e+04, -3.38903817e+04,  2.65404267e+04,
#        -1.06134919e+04, -1.82335589e+03, -1.03025679e+04, -1.84373769e+04,
#        -3.69597327e+04, -2.10740637e+04, -3.36145107e+04,  1.78994926e+04,
#        -8.08925649e+03, -2.11349288e+04])

# %%
mymodel.intercept_
# Out:
# -129732.03182096017

# %%
import pickle

# %%
pickle.dump(mymodel,open("lineartest.pkl",'wb'))

# %%
#Prescriptive analysis
#Do make sure that size is above 32 inch for higher reviews and people prefer any company with a price range between 50,000 to 2,00,000 
#and companies producing a limited number of products go have greater ratings and reviews too. So work on a product that has more value

# %%
df=pd.get_dummies(df)

# %%
df
# Out:
#        Rating  No_of_ratings  Review  Size  RAM    MRP  Company_ALIENWARE
# 0    4.200000            253      20    36   16  59240              False  \
# 1    4.200000            974      75    36    8  60890              False
# 2    4.400000           5389     535    40    8  70990              False
# 3    4.100000            332      26    40    8  58489              False
# 4    4.200000            487      53    40    8  50990              False
# ..        ...            ...     ...   ...  ...    ...                ...
# 979  4.300000            252      29    40    8  93690              False
# 980  3.600000             73      15    40    8  89990              False
# 981  4.253597           2841     241    34   16  76890              False
# 982  4.100000           2581     494    36    8  54490              False
# 983  4.200000            265      21    40    8  76890              False
#
#      Company_APPLE  Company_ASUS  Company_Avita  ...  OpSys_Mac OS
# ...
